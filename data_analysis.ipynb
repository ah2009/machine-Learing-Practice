# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_csv('Datasets/employee_attrition_train.csv')

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  50.0        No      Travel_Rarely     1126.0  Research & Development
# 1  36.0        No      Travel_Rarely      216.0  Research & Development
# 2  21.0       Yes      Travel_Rarely      337.0                   Sales
# 3  50.0        No  Travel_Frequently     1246.0         Human Resources
# 4  52.0        No      Travel_Rarely      994.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0          2        Medical              1             997
# 1               6.0          2        Medical              1             178
# 2               7.0          1      Marketing              1            1780
# 3               NaN          3        Medical              1             644
# 4               7.0          4  Life Sciences              1            1118
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df1 = df.dropna()
df1.count()
# Out:
# Age                         775
# Attrition                   775
# BusinessTravel              775
# DailyRate                   775
# Department                  775
# DistanceFromHome            775
# Education                   775
# EducationField              775
# EmployeeCount               775
# EmployeeNumber              775
# EnvironmentSatisfaction     775
# Gender                      775
# HourlyRate                  775
# JobInvolvement              775
# JobLevel                    775
# JobRole                     775
# JobSatisfaction             775
# MaritalStatus               775
# MonthlyIncome               775
# MonthlyRate                 775
# NumCompaniesWorked          775
# Over18                      775
# OverTime                    775
# PercentSalaryHike           775
# PerformanceRating           775
# RelationshipSatisfaction    775
# StandardHours               775
# StockOptionLevel            775
# TotalWorkingYears           775
# ...

# %%
#Machine Learning start
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
X = df1[['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']]
y = df1.Attrition

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\ale_v\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8298969072164949

# %%
model.score(X_train,y_train)
# Out:
# 0.8313253012048193

# %%
X_test.head()
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 868  29.0      341.0               1.0          3              1
# 444  36.0      607.0               7.0          3              1
# 312  40.0      884.0              15.0          3              1
# 200  53.0      661.0               7.0          2              1
# 247  36.0     1157.0               2.0          4              1
#
#      EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 868             896                        2          48               2
# 444            1362                        1          83               4
# 312            1628                        1          80               2
# 200             862                        1          78               2
# 247            1556                        3          70               3
#
#      JobLevel  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
y_test.head()
# Out:
# 868    Yes
# 444     No
# 312     No
# 200     No
# 247     No
# Name: Attrition, dtype: object

# %%
model.predict(X_test[:5])
# Out:
# array(['No', 'No', 'No', 'No', 'No'], dtype=object)

# %%
X_test[:1]
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 868  29.0      341.0               1.0          3              1
#
#      EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 868             896                        2          48               2
#
#      JobLevel  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 868         1  ...                         3             80                 3
#
#      TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 868                  5                      3                3
#
#      YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 868               3                   2                        0
#
#      YearsWithCurrManager
# 868                     2
#
# [1 rows x 26 columns]

# %%
y_test[:1]
# Out:
# 868    Yes
# Name: Attrition, dtype: object

# %%
#Machine Learing Stopped
model.predict(X_test[:2])
# Out:
# array(['No', 'No'], dtype=object)

# %%
df1.PercentSalaryHike.value_counts()
# Out:
# 13    122
# 14    113
# 12     98
# 11     98
# 15     57
# 17     45
# 19     44
# 18     38
# 16     36
# 20     32
# 22     29
# 21     24
# 23     19
# 25     11
# 24      9
# Name: PercentSalaryHike, dtype: int64

# %%
grp_salary = df1.groupby('PercentSalaryHike').max()[['Age','YearsAtCompany','YearsWithCurrManager','YearsSinceLastPromotion']]

# %%
grp_salary.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
grp_salary.plot(kind='bar')
plt.figure(figsize=(20,3))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="2000">
# <img src="data:image/png;base64,..." width="2000">

# %%
grp2_salary = df1.groupby('PercentSalaryHike').[['Age']]
grp2_salary.plot()
# Out:
#   File "<ipython-input-15-9fcbf177048d>", line 1
#     grp2_salary = df1.groupby('PercentSalaryHike').[['Age']]
#                                                    ^
# SyntaxError: invalid syntax
